# %% [markdown]
# ## COSC 1210
# ### Strings
#
# In this notebook, we will cover
# - string methods
# - stripping white spaces
# - searching strings for substrings
# - splitting strings into tokens
# - concatentating and joining strings

# %% [markdown]
# Strings are...
#
# - immutable
# - iterable

# %%
# A string
astring = "     Python is a versatile, readable language  .\t... \n"
print("*")
print(astring)
print("*")

print("the length is", len(astring))

for i in astring:
    if i == "e":
        print(i)

# %%
# The 3rd index
print(astring[3])

# %%
# The -4 index
print(astring[-4])

# %%
# concatenation
print(astring + astring)

# %%
# repetition and slicing
print(astring[0:10]*3)

# %% [markdown]
# ### Stripping white space
#
# Later we will learn how to process text files with Python. To do so, we can strip the white spaces so we can process the string. Those white spaces include
# - ' ' or '\s'- spaces
# - '\n' - new lines
# - '\t' - tabs

# %%
astring = "     Python is a versatile, readable language  .\t... \n"
# .strip() takes out all white spaces from the ends
print("original")
print(astring)
print("*")
print("stripped")
print(astring.strip())
print("*")

# %%
astring = "     Python is a versatile, readable language  .\t... \n"
print(astring.lstrip())
print("*")

# %%
astring = "     Python is a versatile, readable language  .\t... \n"
print(astring.rstrip())
print("*")

# %% [markdown]
# ### Basic string methods
#
# Test these methods and determine what they do, they're pretty self-explanatory
# - .lower()
# - .upper()
# - .capitalize()
# - .title()

# %%
# test the methods here

# %% [markdown]
# ### String searching
#
# Let's say we want to find substrings in a string

# %%
# how many 'e' characters are in astring?
astring = "     Python is a versatile, readable language  .\t... \n"
astring.count('e')
# Out:
# 5

# %%
# find the index of the first instance of 'e'
astring = "     Python is a versatile, readable language  .\t... \n"
astring.index('e')
# Out:
# 18

# %% [markdown]
# ### Other string methods
#
# - .startswith()
# - .endswith()

# %% [markdown]
# ### Replacing substring, splitting, joining

# %%
# Replacing a substring in a larger string
astring = "     Python is a versatile, readable language  .\t... \n"
astring.replace(" ", "-")
# Out:
# '-----Python-is-a-versatile,-readable-language--.\t...-\n'

# %%
# splitting strings
bstring = "a b c d"
bstring.split() # the default splits on a  __________
# Out:
# ['a', 'b', 'c', 'd']

# %%
# splitting strings
cstring = "a, b, c, d"
cstring.split(', ')
# Out:
# ['a', 'b', 'c', 'd']

# %%
# convert a list to a string with whatever substring between elements in a list
letter_list = ['A', 'B', 'C', 'D']
','.join(letter_list)
# Out:
# 'A,B,C,D'

# %%
## And if you bring in a text file that has many lines...
lines = "This is what a string that comes from a file will look\nAnd each line is seperated by newlines\nAnd you probably want to parse it\n"
print(lines)
# Out:
# This is what a string that comes from a file will look
# And each line is seperated by newlines
# And you probably want to parse it

# %%
lines.splitlines(True) # to make each line into a list
# Out:
# ['This is what a string that comes from a file will look\n',
#  'And each line is seperated by newlines\n',
#  'And you probably want to parse it\n']

# %% [markdown]
# #### **Stop and answer this question**
#
# In the string lines above, there are newline characters. Use the .strip() method to remove the newline ending from each line

# %%
paragraph = (
    "The morning sunlight filtered through the tall oak trees, casting golden patches across the forest floor.\n"
    "Birds sang softly in the distance, their melodies weaving through the crisp air.\n"
    "Each step along the narrow trail stirred the scent of damp earth and pine needles, reminding me how alive the world felt in that quiet hour.\n"
    "For a moment, it seemed as though time had slowed down, allowing nature to breathe in its own rhythm."
)
paragraph.split()
word_dict = {"the": "the", "in": "in", "how" : "how"}
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 7
#       1 paragraph = (
#       2     "The morning sunlight filtered through the tall oak trees, casting golden patches across the forest floor.\n"
#       3     "Birds sang softly in the distance, their melodies weaving through the crisp air.\n"
#       4     "Each step along the narrow trail stirred the scent of damp earth and pine needles, reminding me how alive the world felt in that quiet hour.\n"
#       5     "For a moment, it seemed as though time had slowed down, allowing nature to breathe in its own rhythm."
#       6 )
# ----> 7 paragraph.split('')
#       8 word_dict = {"the": "the", "in": "in", "how" : "how"}
#
# ValueError: empty separator
